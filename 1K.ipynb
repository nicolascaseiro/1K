# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/nicolascaseiro/1K/refs/heads/main/1K.csv", encoding='utf-8')

df.head()
# Out:
#    #                            Música          Artista  Popularidade  BPM  \
# 0  1   Smooth Criminal - 2012 Remaster  Michael Jackson            73  118
# 1  2                       Billie Jean  Michael Jackson            84  117
# 2  3  Smooth Operator - Single Version             Sade            80  119
# 3  4                           Beat It  Michael Jackson            75  139
# 4  5          They Don't Care About Us  Michael Jackson            75   90
#
#                       Gêneros                                        Álbum  \
# 0         dance pop, pop, r&b                         Bad 25th Anniversary
# 1  pop, r&b, disco, dance pop                                     Thriller
# 2      pop, smooth jazz, soul                             The Best of Sade
# 3          pop rock, pop, r&b             Thriller 25 Super Deluxe Edition
# 4         pop rock, pop, rock  HIStory - PAST, PRESENT AND FUTURE - BOOK I
#
#   Data do Álbum Duração  Dançabilidade  ...  Valência  Fala  Ao Vivo  \
# 0    18-09-2012   04:17             85  ...        60     0       30
# 1    30-11-1982   04:54             93  ...        88     0        0
# 2    31-10-1994   04:18             73  ...        96     0        0
# 3    08-02-2008   04:18             78  ...        92     0       20
# 4    16-06-1995   04:44             86  ...        73    10       30
#
#    Volume (dB)          Tom  Compasso  Adicionado em              Spotify ID  \
# 0           -4  G#/A♭ Major         4     2025-08-23  2bCQHF9gdG5BNDVuEIEnNk
# 1          -10      B Minor         4     2025-08-23  7J1uxwnxfQLu4APicE5Rnj
# 2           -7      A Minor         4     2025-08-23  1Hv1VTm8zeOeybub15mA2R
# 3           -4  D#/E♭ Minor         4     2025-08-23  1OOtq8tRnDM8kG2gqUPjAj
# 4           -6      C Minor         4     2025-08-23  3wuCCNCnBhJlwkIJTBZFiv
#
#    Camelot          ISRC
# 0       4B  USSM11204989
# 1      10A  USSM19902991
# 2       8A  GBBBM8400016
# 3       2A  USSM19902990
# 4       5A  USSM19500629
#
# [5 rows x 23 columns]

# %%
linhas, colunas = df.shape[0], df.shape[1]

print(f'Linhas: {linhas}')
print(f'Colunas: {colunas}')
# Out:
# Linhas: 1000
# Colunas: 23

# %%
df.describe()
# Out:
#                  #  Popularidade          BPM  Dançabilidade      Energia  \
# count  1000.000000   1000.000000  1000.000000    1000.000000  1000.000000
# mean    500.500000     72.089000   119.952000      64.168000    70.216000
# std     288.819436     14.090338    27.594803      14.964281    16.771005
# min       1.000000      0.000000    62.000000      18.000000    13.000000
# 25%     250.750000     67.000000    98.000000      54.000000    59.000000
# 50%     500.500000     76.000000   119.000000      66.000000    73.000000
# 75%     750.250000     81.000000   136.250000      75.000000    83.000000
# max    1000.000000     94.000000   206.000000      98.000000   100.000000
#
#           Acústica  Instrumentalidade     Valência         Fala      Ao Vivo  \
# count  1000.000000        1000.000000  1000.000000  1000.000000  1000.000000
# mean     18.103000           2.040000    57.406000     4.980000    15.030000
# std      21.642014           9.864974    23.101707     9.169716    16.669642
# min       0.000000           0.000000     4.000000     0.000000     0.000000
# 25%       2.000000           0.000000    40.000000     0.000000     0.000000
# 50%       8.500000           0.000000    58.000000     0.000000    10.000000
# 75%      27.000000           0.000000    77.000000    10.000000    20.000000
# max      95.000000          91.000000    98.000000    50.000000    90.000000
#
#        Volume (dB)     Compasso
# count   1000.00000  1000.000000
# mean      -6.48200     3.972000
# std        2.87923     0.239318
# min      -21.00000     1.000000
# 25%       -8.00000     4.000000
# 50%       -6.00000     4.000000
# 75%       -4.00000     4.000000
# max       -1.00000     5.000000

# %%
df.corr(numeric_only=True)
# Out:
#                           #  Popularidade       BPM  Dançabilidade   Energia  \
# #                  1.000000     -0.242052  0.057975      -0.099547 -0.050749
# Popularidade      -0.242052      1.000000 -0.078399       0.020072 -0.013776
# BPM                0.057975     -0.078399  1.000000      -0.152357  0.105317
# Dançabilidade     -0.099547      0.020072 -0.152357       1.000000 -0.079231
# Energia           -0.050749     -0.013776  0.105317      -0.079231  1.000000
# Acústica           0.127762     -0.075628 -0.063841      -0.066541 -0.475327
# Instrumentalidade  0.042276      0.021615  0.046780      -0.051743 -0.039029
# Valência           0.003800     -0.075339 -0.007978       0.420416  0.256078
# Fala              -0.052590     -0.004596  0.004229       0.110105  0.047935
# Ao Vivo            0.013089     -0.030376 -0.000454      -0.110935  0.091424
# Volume (dB)       -0.129766      0.080089  0.078653       0.046790  0.661911
# Compasso          -0.064865      0.049126 -0.019302       0.149457  0.122468
#
#                    Acústica  Instrumentalidade  Valência      Fala   Ao Vivo  \
# #                  0.127762           0.042276  0.003800 -0.052590  0.013089
# Popularidade      -0.075628           0.021615 -0.075339 -0.004596 -0.030376
# BPM               -0.063841           0.046780 -0.007978  0.004229 -0.000454
# Dançabilidade     -0.066541          -0.051743  0.420416  0.110105 -0.110935
# Energia           -0.475327          -0.039029  0.256078  0.047935  0.091424
# Acústica           1.000000           0.001547 -0.019753 -0.031692 -0.004295
# Instrumentalidade  0.001547           1.000000 -0.075971 -0.086083 -0.031478
# Valência          -0.019753          -0.075971  1.000000  0.027304 -0.038268
# Fala              -0.031692          -0.086083  0.027304  1.000000  0.062544
# Ao Vivo           -0.004295          -0.031478 -0.038268  0.062544  1.000000
# Volume (dB)       -0.384439          -0.159919  0.068018  0.108827  0.006976
# Compasso          -0.107093           0.008107  0.127349  0.054482  0.012757
#
#                    Volume (dB)  Compasso
# #                    -0.129766 -0.064865
# Popularidade          0.080089  0.049126
# BPM                   0.078653 -0.019302
# Dançabilidade         0.046790  0.149457
# Energia               0.661911  0.122468
# Acústica             -0.384439 -0.107093
# Instrumentalidade    -0.159919  0.008107
# Valência              0.068018  0.127349
# Fala                  0.108827  0.054482
# Ao Vivo               0.006976  0.012757
# Volume (dB)           1.000000  0.132930
# Compasso              0.132930  1.000000

# %%
colunas_numericas = df.select_dtypes(include=['number']).columns

outliers_bool = pd.DataFrame(False, index=df.index, columns=colunas_numericas)

for col in colunas_numericas:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR

    outliers_bool[col] = (df[col] < limite_inferior) | (df[col] > limite_superior)

linhas_com_outliers = outliers_bool.any(axis=1)

df_outliers = df[linhas_com_outliers]

print(f"Total de linhas com pelo menos um outlier: {df_outliers.shape[0]}")
# Out:
# Total de linhas com pelo menos um outlier: 329

# %%
def tempo_para_segundos(tempo_str):
    try:
        minutos, segundos = tempo_str.split(':')
        return int(minutos) * 60 + int(segundos)
    except:
        return None

df['Duração_segundos'] = df['Duração'].apply(tempo_para_segundos)

df['Duração_segundos'] = pd.to_numeric(df['Duração_segundos'], errors='coerce')

duracao_numerica = df['Duração_segundos'].dropna()
Q1 = duracao_numerica.quantile(0.25)
Q3 = duracao_numerica.quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers = df[(df['Duração_segundos'] < limite_inferior) | (df['Duração_segundos'] > limite_superior)]

print(f"Número de outliers na duração: {outliers.shape[0]}\n")

print(outliers[['Música', 'Artista', 'Duração']])
# Out:
# Número de outliers na duração: 41
#
#                                                 Música  \
# 42                                         Money Trees
# 77                                             Runaway
# 81                                             Monster
# 94                                               Roses
# 102    What Goes Around.../...Comes Around (Interlude)
# 104                                            Mirrors
# 119                    Last Night (feat. Keyshia Cole)
# 215                   Hotel California - 2013 Remaster
# 225                                  Master Of Puppets
# 272                                      Let It Happen
# 276                                  Enjoy the Silence
# 300                                   Me and Your Mama
# 352                              No More Parties In LA
# 406                                        Negro Drama
# 407                                       Jesus Chorou
# 420                                   Súplica cearense
# 421                            Anjos (Pra quem tem fé)
# 428                                 Mina do Condomínio
# 480                                 Just the Two of Us
# 481                   So, Tell Me, Tell Me - Vocal Mix
# 482                Life Of The Party (with André 3000)
# 484                                        Saint Pablo
# 492                                               Stan
# 508                             Moonlight on the River
# 542                                Don't Be so Serious
# 543                                     Bury the Light
# 571                                           We Major
# 659                     Don't Stop 'Til You Get Enough
# 720                                              Shout
# 792                                      November Rain
# 802                                         Construção
# 823                             You Don't Know My Name
# 839                                        After Hours
# 844                      New Person, Same Old Mistakes
# 874  Gypsy Woman (She's Homeless) (La Da Dee La Da ...
# 877                                      Paradise City
# 886                                   Comfortably Numb
# 890                      Stairway to Heaven - Remaster
# 893                                        Purple Rain
# 894                                Riders on the Storm
# 988                                      No More Tears
#
#                                              Artista Duração
# 42                           Kendrick Lamar,Jay Rock   06:26
# 77                                Kanye West,Pusha T   09:07
# 81   Kanye West,JAY-Z,Rick Ross,Nicki Minaj,Bon Iver   06:18
# 94                                           Outkast   06:09
# 102                                Justin Timberlake   07:28
# 104                                Justin Timberlake   08:04
# 119                               Diddy,Keyshia Cole   06:28
# 215                                           Eagles   06:31
# 225                                        Metallica   08:35
# 272                                      Tame Impala   07:47
# 276                                     Depeche Mode   06:12
# 300                                 Childish Gambino   06:19
# 352                                       Kanye West   06:14
# 406                                   Racionais MC's   06:51
# 407                                   Racionais MC's   07:51
# 420                                          O Rappa   06:02
# 421                                          O Rappa   06:59
# 428                                        Seu Jorge   06:40
# 480              Bill Withers,Grover Washington, Jr.   07:23
# 481                                         Shavonne   06:37
# 482                            Kanye West,André 3000   06:31
# 484                                       Kanye West   06:12
# 492                                      Eminem,Dido   06:44
# 508                                      Mac DeMarco   07:02
# 542                                         Low Roar   06:13
# 543                                    Casey Edwards   09:40
# 571                        Kanye West,Nas,Really Doe   07:28
# 659                                  Michael Jackson   06:05
# 720                                  Tears For Fears   06:33
# 792                                    Guns N' Roses   08:56
# 802                                    Chico Buarque   06:23
# 823                                      Alicia Keys   06:06
# 839                                       The Weeknd   06:01
# 844                                      Tame Impala   06:03
# 874                 Crystal Waters,The Basement Boys   07:31
# 877                                    Guns N' Roses   06:45
# 886                                       Pink Floyd   06:22
# 890                                     Led Zeppelin   08:02
# 893                                           Prince   08:41
# 894                                        The Doors   07:14
# 988                                    Ozzy Osbourne   07:23

# %%
colunas = list(df.columns)

colunas.remove('Duração_segundos')

idx = colunas.index('Duração')

colunas.insert(idx + 1, 'Duração_segundos')

df = df[colunas]

media_duracao = df['Duração_segundos'].mean()
minutos = int(media_duracao // 60)
segundos = int(media_duracao % 60)
print(f"Média da duração das músicas: {minutos} min {segundos} seg")
# Out:
# Média da duração das músicas: 3 min 59 seg

# %%
df['BPM'] = pd.to_numeric(df['BPM'], errors='coerce')

bpm_validos = df['BPM'].dropna()

Q1 = bpm_validos.quantile(0.25)
Q3 = bpm_validos.quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers_bpm = df[(df['BPM'] < limite_inferior) | (df['BPM'] > limite_superior)]

print(f"Número de outliers de BPM: {outliers_bpm.shape[0]}")
display(outliers_bpm[['Música', 'Artista', 'BPM']])
# Out:
# Número de outliers de BPM: 4
#                Música                            Artista  BPM
# 21    Let Me Love You             DJ Snake,Justin Bieber  200
# 380   I Want You Back                      The Jackson 5  197
# 898  Heart-Shaped Box                            Nirvana  203
# 902   FourFiveSeconds  Rihanna,Kanye West,Paul McCartney  206

# %%
media_bpm = df['BPM'].mean()
print(f"Média do BPM: {media_bpm:.2f}")
# Out:
# Média do BPM: 119.95

# %%
artistas = df['Artista'].dropna().str.split(',').explode().str.strip()

top_artistas = artistas.value_counts().head(10)

top_artistas_df = top_artistas.reset_index()
top_artistas_df.columns = ['Artista', 'Número de Músicas']
top_artistas_df.index = top_artistas_df.index + 1

print("\nTop 10 Artistas com Mais Músicas\n")
print(top_artistas_df.to_string())
# Out:
# Top 10 Artistas com Mais Músicas
#
#            Artista  Número de Músicas
# 1       Kanye West                 37
# 2   Kendrick Lamar                 21
# 3       Bruno Mars                 19
# 4          Rihanna                 18
# 5           Eminem                 15
# 6      Linkin Park                 14
# 7    Justin Bieber                 13
# 8            Drake                 12
# 9            JAY-Z                 12
# 10       Lady Gaga                 11

# %%
df.sort_values(by='Popularidade', ascending=False)[['Música', 'Artista', 'Popularidade']].head(10)
# Out:
#                                                 Música               Artista  \
# 768                                 BIRDS OF A FEATHER         Billie Eilish
# 549                                   Die With A Smile  Lady Gaga,Bruno Mars
# 824                                             Yellow              Coldplay
# 963                                               Iris     The Goo Goo Dolls
# 239                                    Sweater Weather     The Neighbourhood
# 40   All The Stars (with SZA) - From  Black Panther...    Kendrick Lamar,SZA
# 962                                              Creep             Radiohead
# 8                                Every Breath You Take            The Police
# 111                                         In the End           Linkin Park
# 12                                     Blinding Lights            The Weeknd
#
#      Popularidade
# 768            94
# 549            92
# 824            91
# 963            91
# 239            90
# 40             90
# 962            90
# 8              90
# 111            88
# 12             88

# %%
df.sort_values(by='Dançabilidade', ascending=False)[['Música', 'Artista', 'Dançabilidade']].head(10)
# Out:
#                                            Música  \
# 853                                 Give It To Me
# 103                    SexyBack (feat. Timbaland)
# 638                                   Temperature
# 138                           The Real Slim Shady
# 366                                   No More ?'s
# 200                                    Smack That
# 683                         Check Yo Self - Remix
# 588                                    Down Below
# 959  Another One Bites The Dust - Remastered 2011
# 1                                     Billie Jean
#
#                                        Artista  Dançabilidade
# 853  Timbaland,Justin Timberlake,Nelly Furtado             98
# 103                Justin Timberlake,Timbaland             97
# 638                                  Sean Paul             95
# 138                                     Eminem             95
# 366                                     Eazy-E             94
# 200                                Akon,Eminem             94
# 683                           Ice Cube,Das EFX             93
# 588                                Roddy Ricch             93
# 959                                      Queen             93
# 1                              Michael Jackson             93

# %%
media_dancabilidade = df['Dançabilidade'].mean()
print(f"Média da Dançabilidade: {media_dancabilidade:.2f}%")
# Out:
# Média da Dançabilidade: 64.17%

# %%
df.sort_values(by='Energia', ascending=False)[['Música', 'Artista', 'Energia']].head(10)
# Out:
#                               Música                Artista  Energia
# 946                              You           Bad Religion      100
# 926                      Miss Alissa  Eagles Of Death Metal       99
# 305                   American Idiot              Green Day       99
# 307            Welcome To The Jungle          Guns N' Roses       99
# 410                          Só Rezo                NX Zero       98
# 547                   crossing field                   LiSA       98
# 0    Smooth Criminal - 2012 Remaster        Michael Jackson       98
# 877                    Paradise City          Guns N' Roses       98
# 112                            Faint            Linkin Park       98
# 521                          Duality               Slipknot       98

# %%
df.sort_values(by='Valência', ascending=False)[['Música', 'Artista', 'Valência']].head(10)
# Out:
#                                                 Música             Artista  \
# 957                                          September  Earth, Wind & Fire
# 804                        Menina Mulher Da Pele Preta       Jorge Ben Jor
# 704  O Xote das Meninas (Ela Só Quer Só Pensa em Na...        Luiz Gonzaga
# 689                                        Homem Com H      Ney Matogrosso
# 505                                    La Camisa Negra              Juanes
# 771                                    Deixa Acontecer     Grupo Revelação
# 291                                           Rasputin            Boney M.
# 119                    Last Night (feat. Keyshia Cole)  Diddy,Keyshia Cole
# 93                                             Hey Ya!             Outkast
# 866                 Não Quero Dinheiro (Só Quero Amar)            Tim Maia
#
#      Valência
# 957        98
# 804        98
# 704        97
# 689        97
# 505        97
# 771        97
# 291        97
# 119        97
# 93         97
# 866        97

# %%
df.sort_values(by='Volume (dB)', ascending=False)[['Música', 'Artista', 'Volume (dB)']].head(10)
# Out:
#                              Música                            Artista  \
# 812                         Forever  Drake,Kanye West,Lil Wayne,Eminem
# 545         Bangarang (feat. Sirah)                     Skrillex,Sirah
# 461                       Starships                        Nicki Minaj
# 529                       Boom Clap                         Charli xcx
# 522                         Monster                            Skillet
# 547                  crossing field                               LiSA
# 352           No More Parties In LA                         Kanye West
# 391  Play Hard (feat. Ne-Yo & Akon)            David Guetta,Ne-Yo,Akon
# 498         Crank That (Soulja Boy)                         Soulja Boy
# 150            Empire State Of Mind                  JAY-Z,Alicia Keys
#
#      Volume (dB)
# 812           -1
# 545           -2
# 461           -2
# 529           -2
# 522           -2
# 547           -2
# 352           -2
# 391           -2
# 498           -2
# 150           -2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

generos_temp = df['Gêneros'].dropna().apply(lambda x: [g.strip() for g in x.split(',')])
df_temp = df.loc[generos_temp.index].copy()
df_temp['genero'] = generos_temp
df_temp = df_temp.explode('genero')

contagem_generos = df_temp['genero'].value_counts()

plt.figure(figsize=(10,6))
contagem_generos.head(10).plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Top 10 Gêneros Musicais')
plt.ylabel('Quantidade de Músicas')
plt.xlabel('Gêneros')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.ticker as ticker

def formatar_tempo(segundos, pos=None):
    minutos = int(segundos) // 60
    seg = int(segundos) % 60
    return f'{minutos}:{seg:02d}'

plt.figure(figsize=(10, 6))
plt.hist(df['Duração_segundos'].dropna(), bins=30, color='skyblue', edgecolor='black')
plt.title('Distribuição da Duração das Músicas')
plt.xlabel('Duração (min:seg)')
plt.ylabel('Número de Músicas')

ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.FuncFormatter(formatar_tempo))

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.boxplot(df['Duração_segundos'].dropna(), vert=False)
plt.title('Boxplot da Duração das Músicas')
plt.xlabel('Duração (min:seg)')

ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.FuncFormatter(formatar_tempo))

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlação entre variáveis numéricas')
plt.show()

# %%
df_temp_decada = df.copy()

df_temp_decada['Data do Álbum'] = pd.to_datetime(df_temp_decada['Data do Álbum'], errors='coerce', dayfirst=True)

df_temp_decada['Ano'] = df_temp_decada['Data do Álbum'].dt.year
df_temp_decada['Década'] = (df_temp_decada['Ano'] // 10) * 10

popularidade_por_decada = df_temp_decada.groupby('Década')['Popularidade'].mean()

popularidade_por_decada.index = popularidade_por_decada.index.astype(str) + 's'

plt.figure(figsize=(12, 6))
popularidade_por_decada.plot(marker='o')
plt.title('Popularidade Média das Músicas por Década de Lançamento')
plt.xlabel('Década')
plt.ylabel('Popularidade Média')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.49.1-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<26,>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.45)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.3.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.49.1-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 22.1 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 42.5 MB/s eta 0:00:00
# Installing collected packages: pydeck, streamlit
# Successfully installed pydeck-0.9.1 streamlit-1.49.1

# %%
# %%writefile app.py

import streamlit as st
import pandas as pd
import plotly.express as px

st.set_page_config(page_title="Dashboard 1K", layout="wide")

def carregar_dados():
    url = "https://raw.githubusercontent.com/nicolascaseiro/1K/refs/heads/main/1K.csv"
    df = pd.read_csv(url, encoding='utf-8')
    return df

df = carregar_dados()

df['Gêneros'] = df['Gêneros'].fillna('Desconhecido').astype(str)
df['Artista'] = df['Artista'].fillna('Desconhecido').astype(str)

generos_lista = df['Gêneros'].apply(lambda x: [g.strip() for g in x.split(',')])
artistas_lista = df['Artista'].apply(lambda x: [a.strip() for a in x.split(',')])

df_temp = df.copy()
df_temp = df_temp.assign(Gêneros_lista=generos_lista)
df_temp = df_temp.explode('Gêneros_lista')

artistas_lista_temp = artistas_lista.loc[df_temp.index]
df_temp = df_temp.assign(Artistas_lista=artistas_lista_temp)
df_temp = df_temp.explode('Artistas_lista')

df_temp['Data do Álbum'] = pd.to_datetime(df_temp['Data do Álbum'], errors='coerce', dayfirst=True)
df_temp['Ano'] = df_temp['Data do Álbum'].dt.year
df_temp['Década'] = (df_temp['Ano'] // 10) * 10

st.sidebar.header("Filtros")

decadas_disponiveis = sorted(df_temp['Década'].dropna().unique())
generos_disponiveis = sorted(df_temp['Gêneros_lista'].dropna().unique())
artistas_disponiveis = sorted(df_temp['Artistas_lista'].dropna().unique())

decada_selecionada = st.sidebar.multiselect('Filtrar por Década:', decadas_disponiveis)
genero_selecionado = st.sidebar.multiselect('Filtrar por Gênero:', generos_disponiveis)
artista_selecionado = st.sidebar.multiselect('Filtrar por Artista:', artistas_disponiveis)

df_filtrado = df_temp.copy()

if decada_selecionada:
    df_filtrado = df_filtrado[df_filtrado['Década'].isin(decada_selecionada)]

if genero_selecionado:
    df_filtrado = df_filtrado[df_filtrado['Gêneros_lista'].isin(genero_selecionado)]

if artista_selecionado:
    df_filtrado = df_filtrado[df_filtrado['Artistas_lista'].isin(artista_selecionado)]

indices_filtrados = df_filtrado.index.unique()
df_tabela = df.loc[indices_filtrados].copy()

df_tabela['Data do Álbum'] = pd.to_datetime(df_tabela['Data do Álbum'], errors='coerce', dayfirst=True)
df_tabela['Ano'] = df_tabela['Data do Álbum'].dt.year
df_tabela['Década'] = (df_tabela['Ano'] // 10) * 10

total_musicas_filtradas = pd.Series(
    df_tabela['Música'].str.strip().str.lower() + ' - ' + df_tabela['Artista'].str.strip().str.lower()
).nunique()

st.title("Dashboard 1K")

col1, col2, col3, col4 = st.columns(4)
col1.metric("Total de músicas", total_musicas_filtradas)
col2.metric("Média Popularidade", f"{df_filtrado['Popularidade'].mean():.2f}")
col3.metric("Total de Artistas", df_filtrado['Artistas_lista'].nunique())
col4.metric("Total de Gêneros", df_filtrado['Gêneros_lista'].nunique())

st.markdown("---")

df_grafico = df_filtrado.groupby('Gêneros_lista')['Popularidade'].mean().reset_index()

fig = px.bar(df_grafico,
             x='Gêneros_lista',
             y='Popularidade',
             title='Popularidade Média por Gênero Musical',
             labels={'Gêneros_lista': 'Gênero', 'Popularidade': 'Popularidade Média'},
             color='Popularidade',
             color_continuous_scale='Viridis',
             text=df_grafico['Popularidade'].round(2)
            )

fig.update_traces(textposition='outside', marker_line_width=1.5, marker_line_color='black')
fig.update_layout(
    plot_bgcolor='white',
    title_font=dict(size=24, family='Verdana', color='darkblue'),
    xaxis_title_font=dict(size=18, family='Verdana'),
    yaxis_title_font=dict(size=18, family='Verdana'),
    xaxis_tickangle=-45,
    xaxis_tickfont=dict(size=12, family='Verdana'),
    yaxis=dict(range=[0, 100]),
    margin=dict(l=40, r=40, t=80, b=100)
)

st.plotly_chart(fig, width='stretch')

st.markdown("---")

df_tabela['Década'] = df_tabela['Década'].astype(str) + 's'

colunas_exibir = ['Música', 'Artista', 'Gêneros', 'Popularidade', 'Década']
st.dataframe(df_tabela[colunas_exibir])
# Out:
# Overwriting app.py

# %%
artistas_listados = df['Artista'].apply(lambda x: [a.strip() for a in x.split(',')])

# Cria um DataFrame temporário com um artista por linha
df_temp = pd.DataFrame({'Artista': artistas_listados})
df_explodido = df_temp.explode('Artista')

# Conta quantas vezes cada artista aparece
contagem = df_explodido['Artista'].value_counts()

# Filtra artistas que aparecem só uma vez
artistas_unicos = contagem[contagem == 1].index.tolist()

# Visualizar (exemplo: primeiros 10)
print("Total de artistas únicos:", len(artistas_unicos))
print(artistas_unicos)
# Out:
# Total de artistas únicos: 429
# ['One Direction', 'Juelz Santana', 'James Ingram', 'R. Kelly', 'Miike Snow', 'Claudia', "Israel Kamakawiwo'ole", 'Trevor Daniel', 'A-Trak', 'Andrew Wyatt', 'Alice In Chains', 'Soundgarden', 'Bootsy Collins', 'Carly Rae Jepsen', 'Jess Glynne', 'Vanessa Carlton', 'OneRepublic', 'Hayley Williams', 'Train', 'Wyclef Jean', 'Kyla', "Colby O'Donis", 'Kodak Black', 'Wizkid', 'Luiz Melodia', 'Lenine', 'Maria Rita', 'Fundo De Quintal', 'Péricles', 'WILLOW', 'Jack Ü', 'Glass Animals', 'L.V.', 'Coolio', 'Krayzie Bone', 'Chamillionaire', 'Nayer', 'AFROJACK', 'MAGIC!', 'Bebe Rexha', 'G-Eazy', 'Camila Cabello', 'Eagles', 'De La Soul', 'Zara Larsson', 'Tommy Richman', 't.A.T.u.', 'Rick Astley', 'PSY', 'Quavo', 'Smallpools', 'Joy Crookes', 'Jack Harlow', 'The Kid LAROI', 'Kate Bush', 'GIVĒON', 'Amber Coffman', 'Cults', 'Otis Redding', 'Mr. Fantastik', 'Panic! At The Disco', 'The Jackson 5', 'The White Stripes', 'The Wanted', 'Boney M.', 'Alphaville', 'Oasis', 'Kelly Rowland', 'Olivia', 'Krono', 'Luvli', 'Aaron Smith', 'Big Syke', 'Depeche Mode', 'Rockwell', 'Modjo', 'Travie McCoy', 'Kwabs', 'Legião Urbana', 'Ultraje a Rigor', 'Os Paralamas Do Sucesso', 'Kiko Zambianchi', 'Amanda Reifer', 'Blxst', 'Modern Talking', 'ScHoolboy Q', "K'NAAN", 'Freshlyground', 'Mary J. Blige', 'Passenger', 'Tom Odell', 'Lucenzo', 'Don Omar', 'Raimundos', 'Adoniran Barbosa', 'Jim Croce', 'Juice WRLD', 'Bell Biv DeVoe', 'Iyaz', 'Gabry Ponte', 'Eiffel 65', 'Neo Beats', 'MØ', 'Major Lazer', 'KOPPS', 'Joywave', 'Sante Les Amis', 'Jungle', '070 Shake', 'KISS', 'Daryl Hall & John Oates', 'Franz Ferdinand', 'The Rolling Stones', 'MC Eiht', 'Thundercat', 'Dwele', 'LSD', 'Labrinth', 'GALNERYUS', "Destiny's Child", 'Haddaway', 'Alexandra Stan', 'Sabrina Carpenter', 'Capital Inicial', 'CPM 22', 'Bagua Records', 'Xamã', 'Los Palmeras', 'Natalia Lafourcade', 'Los Ángeles Azules', 'Alan Braxe', 'Syleena Johnson', 'Capital Cities', 'Smash Mouth', 'Wanz', 'Nile Rodgers', 'Ray Dalton', 'Kimbra', 'Benjamin Diamond', 'Stardust', 'Taio Cruz', 'Juanes', '*NSYNC', 'Flipmode Squad', 'Busta Rhymes', 'The Game', 'Young Thug', 'Bastille', 'Lil Tecca', 'Swae Lee', 'Shavonne', 'Jr.', 'Grover Washington', 'Bill Withers', 'Bobby Caldwell', 'Engelbert Humperdinck', 'Count Basie', 'Harry Styles', 'Oliver Tree', 'Little Sis Nora', 'AronChupa', 'Dia', 'Meg', 'Dot Exe', 'Whitney Houston', 'Gloria Gaynor', 'Mark Ronson', 'Corona', 'Thomas Bangalter', 'Talent', 'Spice Girls', 'Static Major', 'Miri Ben-Ari', 'Really Doe', 'Anderson .Paak', 'Kacy Hill', 'Sampha', 'D12', 'Wham!', 'LiSA', 'Sirah', 'Jamiroquai', 'Casey Edwards', 'Amerie', 'Uncle Charlie Wilson', 'Dido', 'Lana Del Rey', 'Beach House', 'Ghost', 'Lilly Wood and The Prick', 'Low Roar', 'd4vd', 'Cafuné', 'Nico & Vinz', 'Louis Armstrong', 'Grimes', 'The Mamas & The Papas', 'Ray Charles', 'Bee Gees', 'Paul Anka', 'Lukas Graham', 'Anne-Marie', 'M83', 'Skillet', 'Slipknot', 'Milky Chance', 'Skepta', 'Outlawz', 'ZICO', 'Selena Gomez', 'Manu Chao', '桐生一馬(黒田崇矢)', 'Michael Sembello', 'Player', 'bôa', 'Duran Duran', 'Desireless', 'Saint Motel', "Rag'n'Bone Man", 'Del The Funky Homosapien', 'Robin Schulz', 'Arcane', 'Pomme', 'Marshmello', 'Lorde', 'Padre Marcelo Rossi', 'Fábio Jr.', 'Gotye', 'will.i.am', 'DNCE', 'Lil Jon', 'Chris Martin', 'Bon Iver', 'Estelle', 'George Michael', 'Europe', 'Collage', 'Djo', 'Foreigner', 'Lionel Richie', 'Dead Or Alive', 'DMX', 'bbno$', 'Y2K', 'Disciples', 'Icona Pop', 'DaBaby', 'Teriyaki Boyz', 'Chance the Rapper', 'Fatal', 'Yaki Kadafi', 'KANA-BOON', 'YUI', 'America', 'Dina Rae', 'Sammie', 'Skee-Lo', 'El Cata', 'The Neighbourhood', 'Rael', 'Jennifer Lopez', 'Adam Levine', 'Gym Class Heroes', 'Toquinho', 'A Turma Do Balão Mágico', 'Trem Da Alegria', 'Trem Da Alegria E The Fevers', 'H.E.R.', 'Mapei', 'Hotel Ugly', 'Phil Jay', 'Molella', 'Gala', 'Arizona Zervas', 'Desiigner', 'Gal Costa', 'Ivo Mozart', 'POLLO', 'Arlindo Cruz', 'Ritchie', 'Ney Matogrosso', 'Rik Rok', 'Shaggy', 'Aaron May', 'George Martin', '80purppp', 'The St ...

# %%
df.head(1000)
# Out:
#         #                                    Música  \
# 0       1           Smooth Criminal - 2012 Remaster
# 1       2                               Billie Jean
# 2       3          Smooth Operator - Single Version
# 3       4                                   Beat It
# 4       5                  They Don't Care About Us
# ..    ...                                       ...
# 995   996             Run It! (feat. Juelz Santana)
# 996   997                              Vou Festejar
# 997   998  Você Me Vira A Cabeça (Me Tira Do Sério)
# 998   999                                    A Loba
# 999  1000                                 Meu ébano
#
#                                                Artista  Popularidade  BPM  \
# 0                                      Michael Jackson            73  118
# 1                                      Michael Jackson            84  117
# 2                                                 Sade            80  119
# 3                                      Michael Jackson            75  139
# 4                                      Michael Jackson            75   90
# ..                                                 ...           ...  ...
# 995                          Chris Brown,Juelz Santana            78  101
# 996  Sambabook,Jorge Aragão,Zeca Pagodinho,Elza Soa...            61   98
# 997                                            Alcione            60  182
# 998                                            Alcione            58   99
# 999                                            Alcione            57  164
#
#                                                Gêneros  \
# 0                                  dance pop, pop, r&b
# 1                           pop, r&b, disco, dance pop
# 2                               pop, smooth jazz, soul
# 3                                   pop rock, pop, r&b
# 4                                  pop rock, pop, rock
# ..                                                 ...
# 995                                                r&b
# 996  samba, pagode, mpb, bossa nova, nova mpb, hip ...
# 997                                 samba, pagode, mpb
# 998                                 samba, pagode, mpb
# 999                                 samba, pagode, mpb
#
#                                            Álbum Data do Álbum Duração  \
# 0                           Bad 25th Anniversary    18-09-2012   04:17
# 1                                       Thriller    30-11-1982   04:54
# 2                               The Best of Sade    31-10-1994   04:18
# 3               Thriller 25 Super Deluxe Edition    08-02-2008   04:18
# 4    HIStory - PAST, PRESENT AND FUTURE - BOOK I    16-06-1995   04:44
# ..                                           ...           ...     ...
# 995               Chris Brown (Expanded Edition)    29-11-2005   03:49
# 996               Sambabook Jorge Aragão, Vol. 1    17-06-2016   03:19
# 997                         A Paixão Tem Memória    01-01-2001   04:42
# 998                         A Paixão Tem Memória    01-01-2001   04:24
# 999                              Uma nova paixão    09-06-2005   03:27
#
#      Dançabilidade  ...  Valência  Fala  Ao Vivo  Volume (dB)          Tom  \
# 0               85  ...        60     0       30           -4  G#/A♭ Major
# 1               93  ...        88     0        0          -10      B Minor
# 2               73  ...        96     0        0           -7      A Minor
# 3               78  ...        92     0       20           -4  D#/E♭ Minor
# 4               86  ...        73    10       30           -6      C Minor
# ..             ...  ...       ...   ...      ...          ...          ...
# 995             85  ...        21    10       30           -7  C♯/D♭ Minor
# 996             46  ...        83     0       10          -10      B Minor
# 997             43  ...        26     0       10           -8  F#/G♭ Minor
# 998             64  ...        41     0       20           -9  D#/E♭ Minor
# 999             67  ...        96     0       30           -8      C Major
#
#      Compasso  Adicionado em              Spotify ID  Camelot          ISRC
# 0           4     2025-08-23  2bCQHF9gdG5BNDVuEIEnNk       4B  USSM11204989
# 1           4     2025-08-23  7J1uxwnxfQLu4APicE5Rnj      10A  USSM19902991
# 2           4     2025-08-23  1Hv1VTm8zeOeybub15mA2R       8A  GBBBM8400016
# 3           4     2025-08-23  1OOtq8tRnDM8kG2gqUPjAj       2A  USSM19902990
# 4           4     2025-08-23  3wuCCNCnBhJlwkIJTBZFiv       5A  USSM19500629
# ..        ...            ...                     ...      ...           ...
# 995         4     2025-09-09  7xYnUQigPoIDAMPVK79NEq      12A  USJI10500482
# 996         3     2025-09-09  6eZGI7okD8U3zFCjkz7LEc      10A  BRUKM1600015
# 997         4     2025-09-09  4RGRfGjhTxsCkLaHFF90Bq      11A  BRMCA0100259
# 998         4     2025-09-09  6TJJi1sNzwrUpjlXHXazlz       2A  BRMCA0100253
# 999         4     2025-09-09  0nmEuK27DMGbYmSdh6NtKB       8B  BRESM0500300
#
# [1000 rows x 23 columns]
